# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline 

wcdf= pd.read_csv('sub-est2016_all.csv',encoding = "ISO-8859-1")
airlinedf=pd.read_csv('airline-safety.csv')

# %%
airlinedf.count()
# Out:
# airline                   56
# avail_seat_km_per_week    56
# incidents_85_99           56
# fatal_accidents_85_99     56
# fatalities_85_99          56
# incidents_00_14           56
# fatal_accidents_00_14     56
# fatalities_00_14          56
# dtype: int64

# %%
airline.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# 2                      0                 0
# ...

# %%
airlinedf['total_fatalities']=airlinedf.iloc[4,7].sum()
airlinedf.head()
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14  total_fatalities
# 0                      0                 0                 0
# 1                      1                88                 0
# ...

# %%
airlinebin= airlinedf['airline']
airlinebin
# Out:
# 0                     Aer Lingus
# 1                      Aeroflot*
# 2          Aerolineas Argentinas
# 3                    Aeromexico*
# 4                     Air Canada
# 5                     Air France
# 6                     Air India*
# 7               Air New Zealand*
# 8               Alaska Airlines*
# 9                       Alitalia
# 10            All Nippon Airways
# 11                     American*
# 12             Austrian Airlines
# 13                       Avianca
# 14              British Airways*
# 15               Cathay Pacific*
# 16                China Airlines
# 17                        Condor
# 18                          COPA
# 19            Delta / Northwest*
# 20                      Egyptair
# 21                         El Al
# 22            Ethiopian Airlines
# 23                       Finnair
# 24              Garuda Indonesia
# 25                      Gulf Air
# 26             Hawaiian Airlines
# 27                        Iberia
# ...

# %%
plt.figure(figsize=(12,12))
plt.xticks(rotation=90)
sns.lineplot(x= 'airline', y='fatalities_00_14',data=airlinedf)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.barplot(x='airline', y='fatalities_00_14', data=airlinedf)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.set(style="ticks", palette="pastel")
plt.xticks(rotation=90)
sns.boxplot(x='airline', y='fatalities_00_14', data=airlinedf)
sns.despine(trim=True)
plt.show()

# %%
sns.set()
sns.relplot(x="airline", y="f", col="airline",
            hue="smoker", style="smoker", size="size",
            data=airlinedf);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-38ccef3c8c4e> in <module>
#       2 sns.relplot(x="airline", y="fatalities00_14", col="airline",
#       3             hue="smoker", style="smoker", size="size",
# ----> 4             data=airlinedf);
#
# /anaconda3/envs/thinkful/lib/python3.7/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1574         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1575         markers=markers, dashes=dashes, style_order=style_order,
# -> 1576         legend=legend,
#    1577     )
#    1578
#
# ...

# %%
plt.figure(figsize=(12,12))
plt.xticks(rotation=90)
sns.lineplot(x= 'airline', y='fatalities_00_14',data=airlinedf)
plt.show()
